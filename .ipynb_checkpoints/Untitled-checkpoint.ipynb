# %%
import pandas as pd

# %%
df = pd.read_csv("Resources/Weather_data.csv")
df.head()
# Out:
#    Unnamed: 0           City  Cloudiness Country        Date  Humidity    Lat  \
# 0           0           Hede          20      SE  1559432355       100  60.45
# 1           1      Busselton           0      AU  1559432357        69 -33.64
# 2           2       Havelock          90      US  1559432114        94  34.88
# 3           3  Mount Gambier          90      AU  1559432275       100 -37.83
# 4           4        Rikitea         100      PF  1559432318        79 -23.12
#
#       Lng  Max Temp  Wind Speed
# 0   15.49     48.20        5.82
# 1  115.35     55.99        3.00
# 2  -76.90     75.99        4.70
# 3  140.78     50.00       11.41
# 4 -134.97     73.83       23.40

# %%
renamed_df = df.rename(columns={"Unnamed: 0":"City ID"})

# %%
renamed_df.head()
# Out:
#    City ID           City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0           Hede          20      SE  1559432355       100  60.45
# 1        1      Busselton           0      AU  1559432357        69 -33.64
# 2        2       Havelock          90      US  1559432114        94  34.88
# 3        3  Mount Gambier          90      AU  1559432275       100 -37.83
# 4        4        Rikitea         100      PF  1559432318        79 -23.12
#
#       Lng  Max Temp  Wind Speed
# 0   15.49     48.20        5.82
# 1  115.35     55.99        3.00
# 2  -76.90     75.99        4.70
# 3  140.78     50.00       11.41
# 4 -134.97     73.83       23.40

# %%
final_df = renamed_df.set_index("City ID")
final_df.head()
# Out:
#                   City  Cloudiness Country        Date  Humidity    Lat  \
# City ID
# 0                 Hede          20      SE  1559432355       100  60.45
# 1            Busselton           0      AU  1559432357        69 -33.64
# 2             Havelock          90      US  1559432114        94  34.88
# 3        Mount Gambier          90      AU  1559432275       100 -37.83
# 4              Rikitea         100      PF  1559432318        79 -23.12
#
#             Lng  Max Temp  Wind Speed
# City ID
# 0         15.49     48.20        5.82
# 1        115.35     55.99        3.00
# 2        -76.90     75.99        4.70
# 3        140.78     50.00       11.41
# 4       -134.97     73.83       23.40

# %%
final_df.to_html('data_table.html')
